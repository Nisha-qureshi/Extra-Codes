# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
date=pd.date_range('20180701',periods=4)

# %%
import time
import datetime
#datetime.datetime()

# %%
plt.style.use("ggplot")

# %%
datetime.date.today()
#plt.show()
# Out:
# datetime.date(2019, 6, 21)

# %%
index=pd.Series(datetime.date.today())

# %%
import pandas as pd
df=pd.read_csv("G://data/h-1b-visa/h1b_kaggle.csv")

# %%
df.shape
# Out:
# (3002458, 12)

# %%
df.size
# Out:
# 36029496

# %%
df.ndim
# Out:
# 2

# %%
import pandas as pd

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1               Status  \
# 0           0             1  CERTIFIED-WITHDRAWN
# 1           1             2  CERTIFIED-WITHDRAWN
# 2           2             3  CERTIFIED-WITHDRAWN
# 3           3             4  CERTIFIED-WITHDRAWN
# 4           4             5            WITHDRAWN
#
#                                        EMPLOYER_NAME  \
# 0                             UNIVERSITY OF MICHIGAN
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# ...

# %%
df.rename({"Status":"status","EMPLOYER_NAME":"company","PREVAILING_WAGE":"salary","WORKSITE":"state"},axis=1,inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1               status  \
# 0           0             1  CERTIFIED-WITHDRAWN
# 1           1             2  CERTIFIED-WITHDRAWN
# 2           2             3  CERTIFIED-WITHDRAWN
# 3           3             4  CERTIFIED-WITHDRAWN
# 4           4             5            WITHDRAWN
#
#                                              company  \
# 0                             UNIVERSITY OF MICHIGAN
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# ...

# %%
df["salary"].max()
# Out:
# 6997606720.0

# %%
df["salary"].min()
# Out:
# 0.0

# %%
s=df.groupby(["status"])["company"]

# %%
s

# %%
s=df.sort_values("salary",ascending=False)

# %%
s.head(25)
# Out:
#          Unnamed: 0  Unnamed: 0.1     status  \
# 2163248     2163248       2163249     DENIED
# 2797982     2797982       2797983     DENIED
# 1673867     1673867       1673868     DENIED
# 1819718     1819718       1819719     DENIED
# 2775906     2775906       2775907     DENIED
# 1547574     1547574       1547575     DENIED
# 1668384     1668384       1668385     DENIED
# 1805875     1805875       1805876     DENIED
# 2796071     2796071       2796072  WITHDRAWN
# 1698325     1698325       1698326     DENIED
# 2586866     2586866       2586867     DENIED
# 1780069     1780069       1780070     DENIED
# 2184108     2184108       2184109  WITHDRAWN
# 2190087     2190087       2190088     DENIED
# 2191003     2191003       2191004     DENIED
# 2685667     2685667       2685668     DENIED
# 2522246     2522246       2522247     DENIED
# 2921196     2921196       2921197     DENIED
# 5579           5579          5580     DENIED
# 2831024     2831024       2831025     DENIED
# ...

# %%
s.groupby(["company"])
