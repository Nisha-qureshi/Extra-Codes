# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(-5,5,1000)
# %matplot_inline
# print(x)
# Out:
# UsageError: Line magic function `%matplot_inline` not found.

# %%
x=np.linspace(-27,56,10)

# %%
x
# Out:
# array([-27.        , -17.77777778,  -8.55555556,   0.66666667,
#          9.88888889,  19.11111111,  28.33333333,  37.55555556,
#         46.77777778,  56.        ])

# %%
mod_x=abs(x)
plt.plot(x,mod_x,labels=x,y) #--> bydefault lines in graph are in 'b-' means blue line
plt.title("Graph")
plt.legend()
plt.show()
# Out:
#   File "<ipython-input-13-d0f287fd57d7>", line 2
#     plt.plot(x,mod_x,labels=x,y) #--> bydefault lines in graph are in 'b-' means blue line
#                              ^
# SyntaxError: positional argument follows keyword argument

# %%
x=np.linspace(-5,5,100)
x_sq=x**2
y=np.sqrt(100-x**2)
fig=plt.figure(figsize=(4,3))
f1=fig.add_axes([0,0,1,1])
ax1=fig.add_axes([0.1,0.1,0.3,0.3])
ax2=fig.add_axes([0.5,0.4,0.3,0.3])
ax3=fig.add_axes([0.1,0.5,0.3,0.3])
ax4=fig.add_axes([0.7,0.3,0.3,0.3])
ax1.plot(x,label="x",c="g")
ax2.plot(x_sq,label="sqr(x)")
ax3.plot(y,label="y",c="k")
ax4.plot(x,y)
ax1.legend()
ax2.legend()
ax3.legend()
plt.show()

# %%
fig=plt.figure()
f1=fig.add_axes([0,0,1,1])
ax1=fig.add_axes([0.5,0.3,0.4,0.5])
y1=x
y2=x**2
y3=x**3
f1.plot(y1,label="x",c="r")  # if we don't provide label then legend will be a empty box
f1.legend()
ax1.plot(y2,"g--",y3,label="x^2")
ax1.legend()

# %%
# make subplot of size (5,3)
fig=plt.figure(figsize=(5,3)) #5-->width and 3--->for height
ax1=fig.add_subplot(111)
ax1.plot()
plt.xlabel("hii i am x",color="b",fontsize=23)
plt.ylabel("i am y",color="g",fontsize=22)
plt.show()

# %%
from matplotlib import pyplot as plt
plt.plot([1,9,3],[4,5,6])
plt.title("first graph",fontsize=20)
plt.xlabel("x -->",color="r",fontsize=16)
plt.ylabel("y -->",color="r",fontsize=16)
plt.grid()    #---> will show grid on graph
plt.show()
#%matplot inline -->to show line to line

# %% [markdown]
# ## linear graph

# %%
from matplotlib import pyplot as plt
from matplotlib import style
style.use("ggplot") # shows light blue color in background
plt.plot([1,9,3],"g",label="[1,9,3]",linewidth=2)
plt.plot([4,5,6],c="c",label="[4,5,6]",lw=4)
plt.title("first graph",fontsize=20)
plt.xlabel("x -->",fontsize=16)
plt.ylabel("y -->",fontsize=16)
plt.legend()     #-->will print the label for all line
plt.grid(True,color='b')    #---> will show grid on graph
plt.show()
#%matplot inline -->to show line to line

# %%
from matplotlib import style
style.use("ggplot")
plt.plot([1,2])
plt.show()

# %% [markdown]
# ## bar graph --> use to compare thing

# %%
plt.bar([1,2],[4,6],label="first",color="g")
# Out:
# <BarContainer object of 2 artists>

# %%
plt.bar(2,40,label="first")
#plt.grid(color="k",linestyle=':',linewidth=3) #k--->black
plt.grid(color="k",ls=':',lw=3) 
plt.show()

# %%
plt.plot([1,2],[10,70],"k-+")
plt.plot(x**2,"r--",x,label="x")
plt.legend()
plt.show()

# %%
graph1=plt.figure(figsize=(22,3))
g1=graph1.add_axes([0,0,1,1])
g2=graph1.add_axes([0.1,0.1,0.8,0.8])
g2.plot(34)
#plt.grid()#-->will remove all grids either above statement exist or not
plt.show()

# %%
line, = plt.plot([1,5],[5,9], '-')
line.set_antialiased(False) # turn off antialising
plt.show()

# %%
from matplotlib import pyplot as plt
df=[[2,3,5,5,6,]]
plt.plot( 'x', 'y', data=df, linestyle='none', marker='D', markersize=16, markeredgecolor="orange", markeredgewidth=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-1c1aa231c40f> in <module>()
#       1 from matplotlib import pyplot as plt
#       2 df=[[2,3,5,5,6,]]
# ----> 3 plt.plot( 'x', 'y', data=df, linestyle='none', marker='D', markersize=16, markeredgecolor="orange", markeredgewidth=5)
#       4 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1822                     args = tuple(_replacer(data, a)
#    1823                                  if _arg_names[j] in replace_names else a
# -> 1824                                  for j, a in enumerate(args))
#    1825
# ...
